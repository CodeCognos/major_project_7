# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('AMCAT_RANK_on_total_score.xlsx')

# %%
df
# Out:
#       Unnamed: 0          Unnamed: 1  Unnamed: 2 English\n(Out Of 900)  \
# 0      21BCS6845     VANSH CHAUDHARY  BE-CSE-AIT                   774
# 1      21BCS6942       TEJAS MUSADDI  BE-CSE-AIT                   720
# 2      21BCS8469        ASHISH RAWAT      BE-CSE                   702
# 3     21BCS11823           Yash Jain      BE-CSE                   702
# 4      21BCS7296         SHIVAM NEGI      BE-CSE                   747
# ...          ...                 ...         ...                   ...
# 5787   21BCS9845       PRAKASH NAVIN  BE-CSE-AIT                Absent
# 5788   21CBS1062  SAURABH KASHAUDHAN  BE-CSE-AIT                Absent
# 5789   21CBS1081      DEBOPRIYO NATH  BE-CSE-AIT                Absent
# 5790   21BET1016  HRISHU KUMAR SINGH   BE-CSE-IT      sufficient attem
# 5791   21BET1091    HARSH KHANDELWAL   BE-CSE-IT                Absent
#
#      Quant\n(Out Of 900) Logical\n(Out Of 900) CP\n(Out Of 900)  \
# ...

# %%
df.shape
# Out:
# (5792, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0          Unnamed: 1  Unnamed: 2 English\n(Out Of 900)  \
# 0      21BCS6845     VANSH CHAUDHARY  BE-CSE-AIT                   774
# 1      21BCS6942       TEJAS MUSADDI  BE-CSE-AIT                   720
# 2      21BCS8469        ASHISH RAWAT      BE-CSE                   702
# 3     21BCS11823           Yash Jain      BE-CSE                   702
# 4      21BCS7296         SHIVAM NEGI      BE-CSE                   747
# ...          ...                 ...         ...                   ...
# 5787   21BCS9845       PRAKASH NAVIN  BE-CSE-AIT                Absent
# 5788   21CBS1062  SAURABH KASHAUDHAN  BE-CSE-AIT                Absent
# 5789   21CBS1081      DEBOPRIYO NATH  BE-CSE-AIT                Absent
# 5790   21BET1016  HRISHU KUMAR SINGH   BE-CSE-IT      sufficient attem
# 5791   21BET1091    HARSH KHANDELWAL   BE-CSE-IT                Absent
#
#      Quant\n(Out Of 900) Logical\n(Out Of 900) CP\n(Out Of 900)  \
# ...

# %%
# Check for null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Unnamed: 1                    1
# Unnamed: 2                    0
# English\n(Out Of 900)         0
# Quant\n(Out Of 900)           0
# Logical\n(Out Of 900)         0
# CP\n(Out Of 900)              0
# Domain Score\n(Out Of 900)    0
# Automata\n(Out Of 100)        0
# Automata fix\n(Out Of 100)    0
# writex\n(Out Of 900)          0
# Total                         0
# dtype: int64

# %%
df['English\n(Out Of 900)'].unique()
# Out:
# array([774, 720, 702, 747, 729, 711, 648, 684, 639, 693, 756, 801, 603,
#        792, 657, 576, 738, 837, 585, 666, 612, 594, 675, 765, 531, 621,
#        819, 558, 783, 630, 549, 567, 540, 486, 513, 450, 810, 522, 495,
#        504, 432, 414, 468, 477, 459, 396, 351, 405, 369, 441, 423, 360,
#        378, 324, 387, 'sufficient attem', 297, 261, 342, 279, 333, 306,
#        315, 288, 270, 243, 234, 207, 252, 198, 'Absent'], dtype=object)

# %%
df['Quant\n(Out Of 900)'].unique()
# Out:
# array([801, 729, 756, 747, 765, 693, 774, 720, 711, 738, 621, 675, 702,
#        648, 639, 684, 666, 657, 567, 558, 612, 549, 531, 594, 783, 630,
#        576, 540, 585, 603, 522, 792, 486, 477, 495, 504, 468, 459, 450,
#        441, 513, 432, 414, 396, 360, 387, 324, 423, 297, 405, 378, 369,
#        351, 315, 270, 342, 'Insufficient attempts', 306, 333, 279, 225,
#        288, 207, 261, 234, 252, 243, 216, 189, 171, 198, 162, 180,
#        'Unattempted', 'Absent'], dtype=object)

# %%
df['Logical\n(Out Of 900)'].unique()
# Out:
# array([621, 675, 594, 720, 657, 450, 549, 639, 702, 684, 666, 585, 576,
#        729, 567, 711, 603, 558, 693, 630, 432, 504, 612, 459, 648, 522,
#        513, 531, 414, 468, 495, 387, 477, 423, 540, 738, 486, 441, 378,
#        342, 333, 396, 360, 270, 351, 369, 324, 297, 405, 306, 315, 261,
#        279, 252, 'Insufficient attempts', 234, 207, 288, 216, 243, 171,
#        198, 162, 189, 144, 153, 126, 180, 108, 225, 'Unattempted',
#        'Absent'], dtype=object)

# %%
df['CP\n(Out Of 900)'].unique()
# Out:
# array([603, 747, 729, 567, 720, 666, 711, 702, 576, 639, 657, 531, 675,
#        630, 612, 684, 585, 738, 648, 621, 594, 549, 774, 693, 765, 504,
#        756, 522, 540, 558, 450, 477, 513, 459, 432, 495, 441, 486, 369,
#        414, 387, 468, 423, 405, 306, 378, 342, 396, 324, 270, 333, 297,
#        279, 117, 351, 360, 261, 216, 288, 36, 27, 234, 243, 207, 171, 225,
#        108, 315, 126, 162, 252, 189, 144, 99, 45, 54, 81, 198, 180, 153,
#        135, 72, 9, 63, 0, 'sufficient attemp', 90, 18, 'Unattempted',
#        'Absent'], dtype=object)

# %%
df['Domain Score\n(Out Of 900)'].unique()
# Out:
# array([900, 810, 891, 837, 819, 711, 765, 873, 747, 882, 774, 828, 756,
#        846, 801, 855, 729, 594, 864, 657, 792, 783, 720, 693, 666, 684,
#        702, 540, 531, 639, 630, 648, 621, 675, 513, 549, 612, 603, 468,
#        576, 477, 504, 738, 414, 585, 567, 522, 423, 558, 450, 441, 459,
#        432, 495, 486, 342, 360, 171, 405, 378, 315, 351, 387, 306, 324,
#        396, 369, 234, 270, 261, 180, 198, 207, 225, 'Unattempted', 153,
#        297, 135, 216, 45, 108, 243, 333, 252, 162, 36,
#        'nsufficient attemp', 189, 144, 279, 126, 288, 117, 63, 54, 99, 81,
#        90, 27, 72, 0, 'Absent'], dtype=object)

# %%
df['Automata\n(Out Of 100)'].unique()
# Out:
# array([68, 50, 43, 99, 51, 95, 87, 28, 62, 97, 60, 78, 59, 72, 83, 25, 82,
#        47, 90, 100, 73, 56, 65, 75, 76, 42, 93, 33, 0, 39, 6, 74, 23, 9,
#        18, 91, 8, 44, 71, 98, 55, 53, 22, 84, 96, 70, 63, 48, 89, 86, 4,
#        11, 21, 64, 92, 52, 66, 54, 94, 61, 5, 14, 45, 79, 67, 77, 85, 57,
#        40, 69, 80, 31, 41, 34, 37, 27, 58, 16, 81, 35, 36, 88, 46, 13, 30,
#        26, 12, 38, 32, 49, 24, 15, 19, 29, 17, 20, 7, 10, 'Unattempted',
#        'Absent'], dtype=object)

# %%
df['Automata fix\n(Out Of 100)'].unique()
# Out:
# array([72, 29, 58, 86, 100, 43, 15, 0, 'Unattempted', 'Absent'],
#       dtype=object)

# %%
df['writex\n(Out Of 900)'].unique()
# Out:
# array([738, 693, 720, 675, 711, 747, 666, 702, 729, 765, 594, 684, 639,
#        576, 630, 657, 486, 648, 603, 756, 540, 585, 477, 567, 531, 612,
#        549, 504, 558, 792, 513, 522, 315, 774, 621, 495, 432, 387, 324,
#        801, 333, 396, 783, 423, 450, 45, 369, 414, 468, 441, 405, 378,
#        243, 306, 459, 261, 270, 342, 360, 279, 234, 288, 225, 351, 252,
#        297, 207, 819, 81, 'Unattempted', 198, 216, 0, 'Absent'],
#       dtype=object)

# %%
df['Total'].unique()
# Out:
# array([5378, 5272, 5258, ...,  405,  324,    0], dtype=int64)

# %%
# Remove student records with un attempted ,absent

# %%
# Rename columns 
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Unnamed: 1                    1
# Unnamed: 2                    0
# English\n(Out Of 900)         0
# Quant\n(Out Of 900)           0
# Logical\n(Out Of 900)         0
# CP\n(Out Of 900)              0
# Domain Score\n(Out Of 900)    0
# Automata\n(Out Of 100)        0
# Automata fix\n(Out Of 100)    0
# writex\n(Out Of 900)          0
# Total                         0
# dtype: int64

# %%
df1 = df.rename(columns={
    'Unnamed: 0': 'uid',
    'Unnamed: 1': 'Name',
    'Unnamed: 2': 'Department',
    'English\n(Out Of 900)': 'English',
    'Quant\n(Out Of 900)': 'Quant',
    'Logical\n(Out Of 900)': 'Logical',
    'CP\n(Out Of 900)': 'CP',
    'Domain Score\n(Out Of 900)': 'Domain Score',
    'Automata\n(Out Of 100)': 'Automata',
    'Automata fix\n(Out Of 100)': 'Automata fix',
    'writex\n(Out Of 900)': 'writex'  # Corrected line
})

print(df1)
# Out:
#              uid                Name  Department           English  \
# 0      21BCS6845     VANSH CHAUDHARY  BE-CSE-AIT               774
# 1      21BCS6942       TEJAS MUSADDI  BE-CSE-AIT               720
# 2      21BCS8469        ASHISH RAWAT      BE-CSE               702
# 3     21BCS11823           Yash Jain      BE-CSE               702
# 4      21BCS7296         SHIVAM NEGI      BE-CSE               747
# ...          ...                 ...         ...               ...
# 5787   21BCS9845       PRAKASH NAVIN  BE-CSE-AIT            Absent
# 5788   21CBS1062  SAURABH KASHAUDHAN  BE-CSE-AIT            Absent
# 5789   21CBS1081      DEBOPRIYO NATH  BE-CSE-AIT            Absent
# 5790   21BET1016  HRISHU KUMAR SINGH   BE-CSE-IT  sufficient attem
# 5791   21BET1091    HARSH KHANDELWAL   BE-CSE-IT            Absent
#
#             Quant      Logical           CP Domain Score     Automata  \
# 0             801          621          603          900           68
# ...

# %%
# checking unique values in department column

# %%
df1['Department'].unique()
# Out:
# array(['BE-CSE-AIT', 'BE-CSE', 'BE-CSE-IT'], dtype=object)

# %%
# REMOVE ABSENT STUDENTS

# %%
df_cleaned = df1.replace(['Absent', 'Unattempted'], pd.NA).dropna()

print(df_cleaned)
# Out:
#              uid             Name  Department English                  Quant  \
# 0      21BCS6845  VANSH CHAUDHARY  BE-CSE-AIT     774                    801
# 1      21BCS6942    TEJAS MUSADDI  BE-CSE-AIT     720                    729
# 2      21BCS8469     ASHISH RAWAT      BE-CSE     702                    756
# 3     21BCS11823        Yash Jain      BE-CSE     702                    747
# 4      21BCS7296      SHIVAM NEGI      BE-CSE     747                    729
# ...          ...              ...         ...     ...                    ...
# 5546   21BCS5609      JYOTI VERMA      BE-CSE     234                    189
# 5547  22BCS80226   TABISH HUSSAIN      BE-CSE     405                    207
# 5548  21BCS11296             YASH      BE-CSE     279                    234
# 5549   21BCS9966   VEDANSH TIWARI      BE-CSE     459  Insufficient attempts
# 5552   21BCS7170  ANMOL KAUR GILL      BE-CSE     261                    279
#
# ...

# %%
df1_cleaned = df_cleaned.replace(['sufficient attem','Insufficient attempts' ,'sufficient attemp' ,'nsufficient attemp'],pd.NA).dropna()

# %%
df1_cleaned.head()
# Out:
#           uid             Name  Department English Quant Logical   CP  \
# 0   21BCS6845  VANSH CHAUDHARY  BE-CSE-AIT     774   801     621  603
# 1   21BCS6942    TEJAS MUSADDI  BE-CSE-AIT     720   729     675  747
# 2   21BCS8469     ASHISH RAWAT      BE-CSE     702   756     594  729
# 3  21BCS11823        Yash Jain      BE-CSE     702   747     720  567
# 4   21BCS7296      SHIVAM NEGI      BE-CSE     747   729     657  720
#
#   Domain Score  Automata  Automata fix  writex  Total
# 0          900        68            72     738   5378
# 1          900        50            29     693   5272
# 2          900        43            58     720   5258
# 3          900        99            86     675   5243
# 4          810        51            86     711   5240

# %%
df1_cleaned.shape
# Out:
# (5221, 12)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming 'Department' column exists)
# Group by the Department column and count the occurrences
department_counts = df1_cleaned['Department'].value_counts()

# Plot the bar graph
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x=department_counts.index, y=department_counts.values, palette='viridis')

# Adding labels and title
plt.title('Count of Students by Department', fontsize=16)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)

# Rotate x labels for better readability if necessary
plt.xticks(rotation=45)

# Annotate the bars with the count of students
for index, value in enumerate(department_counts.values):
    plt.text(index, value + 5, str(value), ha='center', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting highest values
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
highest_values.plot(kind='bar', color='green')
plt.title('Highest Values')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.xticks(rotation=45)

# Plotting lowest values
plt.subplot(1, 2, 2)
lowest_values.plot(kind='bar', color='red')
plt.title('Lowest Values')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       4 plt.figure(figsize=(14, 7))
#       6 plt.subplot(1, 2, 1)
# ----> 7 highest_values.plot(kind='bar', color='green')
#       8 plt.title('Highest Values')
#       9 plt.xlabel('Subjects')
#
# NameError: name 'highest_values' is not defined

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Sample DataFrame loading (you'll need to load your actual data)
# df = pd.read_csv('your_dataset.csv')

# Selecting only the columns with marks
marks_columns = ['English', 'Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex', 'Total']

# Finding highest and lowest values
highest_values = df1_cleaned[marks_columns].max()
lowest_values = df1_cleaned[marks_columns].min()

print("Highest Values:\n", highest_values)
print("\nLowest Values:\n", lowest_values)

# %%
import matplotlib.pyplot as plt

# Plotting highest values
plt.figure(figsize=(14, 7))

# Plotting Highest Values
plt.subplot(1, 2, 1)
bars_highest = plt.bar(highest_values.index, highest_values, color='green')
plt.title('Highest Values')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.xticks(rotation=45)

# Add numeric values on bars
for bar in bars_highest:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom')  # va='bottom' places the text above the bar

# Plotting Lowest Values
plt.subplot(1, 2, 2)
bars_lowest = plt.bar(lowest_values.index, lowest_values, color='red')
plt.title('Lowest Values')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.xticks(rotation=45)

# Add numeric values on bars
for bar in bars_lowest:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom')  # va='bottom' places the text above the bar

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       6 # Plotting Highest Values
#       7 plt.subplot(1, 2, 1)
# ----> 8 bars_highest = plt.bar(highest_values.index, highest_values, color='green')
#       9 plt.title('Highest Values')
#      10 plt.xlabel('Subjects')
#
# NameError: name 'highest_values' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Example of setting a threshold (e.g., 60)
threshold = 700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Train the RandomForestClassifier model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# Print classification report for each target
for i, column in enumerate(target.columns):
    print(f"Classification report for {column}:")
    print(classification_report(y_test[column], y_pred[:, i]))
# Out:
# Classification report for Automata_Weak:
#               precision    recall  f1-score   support
#
#         True       1.00      1.00      1.00      1567
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
#
# Classification report for Domain_Weak:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       502
#         True       1.00      1.00      1.00      1065
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_clean is already prepared)
threshold = 60
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize RandomForestClassifier
model = RandomForestClassifier(random_state=42)

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=model,
                           param_grid=param_grid,
                           cv=5,  # Number of cross-validation folds
                           n_jobs=-1,  # Use all available cores
                           verbose=2)  # Increase verbosity for debugging

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Train model with the best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Print classification report for each target
for i, column in enumerate(target.columns):
    print(f"Classification report for {column}:")
    print(classification_report(y_test[column], y_pred[:, i]))

# Confusion matrix for one of the target variables (e.g., 'Automata_Weak')
conf_matrix = confusion_matrix(y_test['Automata_Weak'], y_pred[:, 0])
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Weak', 'Weak'],
            yticklabels=['Not Weak', 'Weak'])
plt.title('Confusion Matrix for Automata_Weak')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Feature importance
importances = best_model.feature_importances_
feature_names = features.columns
indices = importances.argsort()[::-1]

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title('Feature Importances')
plt.bar(range(len(feature_names)), importances[indices], align='center')
plt.xticks(range(len(feature_names)), [feature_names[i] for i in indices], rotation=45)
plt.xlim([-1, len(feature_names)])
plt.show()
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Best score: 0.9994528043775649
# Classification report for Automata_Weak:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       344
#         True       1.00      1.00      1.00      1223
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
#
# Classification report for Domain_Weak:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1555
#         True       1.00      0.92      0.96        12
#
#     accuracy                           1.00      1567
#    macro avg       1.00      0.96      0.98      1567
# weighted avg       1.00      1.00      1.00      1567

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_clean is already prepared)
threshold = 700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize models
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Support Vector Classifier': SVC(probability=True, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# Define parameter grids for GridSearchCV
param_grids = {
    'Random Forest': {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    },
    'Logistic Regression': {
        'C': [0.1, 1, 10],
        'penalty': ['l2']
    },
    'Support Vector Classifier': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf']
    },
    'Gradient Boosting': {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5]
    }
}

# Function to train and evaluate models
def train_and_evaluate(model_name, model, param_grid):
    print(f"\nTraining and evaluating {model_name}...")
    
    # Hyperparameter tuning
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    
    # Print classification report
    print(f"Best parameters for {model_name}:", grid_search.best_params_)
    for i, column in enumerate(target.columns):
        print(f"\nClassification report for {column} using {model_name}:")
        print(classification_report(y_test[column], y_pred[:, i]))
    
    # Confusion matrix for one of the target variables (e.g., 'Automata_Weak')
    conf_matrix = confusion_matrix(y_test['Automata_Weak'], y_pred[:, 0])
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Not Weak', 'Weak'],
                yticklabels=['Not Weak', 'Weak'])
    plt.title(f'Confusion Matrix for Automata_Weak using {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Train and evaluate all models
for name, model in models.items():
    train_and_evaluate(name, model, param_grids[name])
# Out:
# Training and evaluating Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for Random Forest: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
#
# Classification report for Automata_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#         True       1.00      1.00      1.00      1567
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
#
#
# Classification report for Domain_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       502
#         True       1.00      1.00      1.00      1065
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_cleaned is already prepared)
threshold = 700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize models
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Support Vector Classifier': SVC(probability=True, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# Define parameter grids for GridSearchCV
param_grids = {
    'Random Forest': {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    },
    'Logistic Regression': {
        'C': [0.1, 1, 10],
        'penalty': ['l2']
    },
    'Support Vector Classifier': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf']
    },
    'Gradient Boosting': {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5]
    }
}

# Function to train and evaluate models
def train_and_evaluate(model_name, model, param_grid):
    print(f"\nTraining and evaluating {model_name}...")
    
    # Hyperparameter tuning
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    
    # Print classification reports
    print(f"Best parameters for {model_name}:", grid_search.best_params_)
    for i, column in enumerate(target.columns):
        print(f"\nClassification report for {column} using {model_name}:")
        print(classification_report(y_test[column], y_pred[:, i]))
    
    # Confusion matrices for each target variable
    for i, column in enumerate(target.columns):
        conf_matrix = confusion_matrix(y_test[column], y_pred[:, i])
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Weak', 'Weak'],
                    yticklabels=['Not Weak', 'Weak'])
        plt.title(f'Confusion Matrix for {column} using {model_name}')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()

# Train and evaluate all models
for name, model in models.items():
    train_and_evaluate(name, model, param_grids[name])
# Out:
# Training and evaluating Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for Random Forest: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
#
# Classification report for Automata_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#         True       1.00      1.00      1.00      1567
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
#
#
# Classification report for Domain_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       502
#         True       1.00      1.00      1.00      1065
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_cleaned is already prepared)
threshold_1 = 70
threshold_2 =700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold_1
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold_2

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize models
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Support Vector Classifier': SVC(probability=True, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# Define parameter grids for GridSearchCV
param_grids = {
    'Random Forest': {
        'estimator__n_estimators': [100, 200, 300],
        'estimator__max_depth': [None, 10, 20, 30],
        'estimator__min_samples_split': [2, 5, 10]
    },
    'Logistic Regression': {
        'estimator__C': [0.1, 1, 10],
        'estimator__penalty': ['l2']
    },
    'Support Vector Classifier': {
        'estimator__C': [0.1, 1, 10],
        'estimator__kernel': ['linear', 'rbf']
    },
    'Gradient Boosting': {
        'estimator__n_estimators': [100, 200],
        'estimator__learning_rate': [0.01, 0.1],
        'estimator__max_depth': [3, 5]
    }
}

# Function to train and evaluate models
def train_and_evaluate(model_name, model, param_grid):
    print(f"\nTraining and evaluating {model_name}...")
    
    # Wrap the model with MultiOutputClassifier
    multi_target_model = MultiOutputClassifier(model, n_jobs=-1)
    
    # Hyperparameter tuning
    grid_search = GridSearchCV(multi_target_model, param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    
    # Print classification reports
    print(f"Best parameters for {model_name}:", grid_search.best_params_)
    for i, column in enumerate(target.columns):
        print(f"\nClassification report for {column} using {model_name}:")
        print(classification_report(y_test[column], y_pred[:, i]))
    
    # Confusion matrices for each target variable
    for i, column in enumerate(target.columns):
        conf_matrix = confusion_matrix(y_test[column], y_pred[:, i])
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Weak', 'Weak'],
                    yticklabels=['Not Weak', 'Weak'])
        plt.title(f'Confusion Matrix for {column} using {model_name}')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()

# Train and evaluate all models
for name, model in models.items():
    train_and_evaluate(name, model, param_grids[name])
# Out:
# Training and evaluating Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for Random Forest: {'estimator__max_depth': None, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100}
#
# Classification report for Automata_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       218
#         True       1.00      1.00      1.00      1349
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# weighted avg       1.00      1.00      1.00      1567
#
#
# Classification report for Domain_Weak using Random Forest:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       502
#         True       1.00      1.00      1.00      1065
#
#     accuracy                           1.00      1567
#    macro avg       1.00      1.00      1.00      1567
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_cleaned is already prepared)
threshold_1 = 70
threshold_2 = 700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold_1
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold_2

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize Logistic Regression model
logistic_model = LogisticRegression(max_iter=1000, random_state=42)

# Wrap the model with MultiOutputClassifier
multi_target_model = MultiOutputClassifier(logistic_model, n_jobs=-1)

# Train the model
multi_target_model.fit(X_train, y_train)

# Make predictions
y_pred = multi_target_model.predict(X_test)

# Print classification reports
for i, column in enumerate(target.columns):
    print(f"\nClassification report for {column} using Logistic Regression:")
    print(classification_report(y_test[column], y_pred[:, i]))

# Plot confusion matrices for each target variable
for i, column in enumerate(target.columns):
    conf_matrix = confusion_matrix(y_test[column], y_pred[:, i])
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Not Weak', 'Weak'],
                yticklabels=['Not Weak', 'Weak'])
    plt.title(f'Confusion Matrix for {column} using Logistic Regression')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# %%
# Check class distribution in the training set
for column in y_train.columns:
    print(f"\nClass distribution for {column} in training set:")
    print(y_train[column].value_counts())

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (assuming df1_cleaned is already prepared)
threshold_1 = 70
threshold_2 = 700
df1_cleaned['Automata_Weak'] = df1_cleaned['Automata'] < threshold_1
df1_cleaned['Domain_Weak'] = df1_cleaned['Domain Score'] < threshold_2

# Define features and target for the classification model
features = df1_cleaned[['Quant', 'Logical', 'CP', 'Domain Score', 'Automata', 'Automata fix', 'writex']]
target = df1_cleaned[['Automata_Weak', 'Domain_Weak']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize models
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Support Vector Classifier': SVC(probability=True, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# Define parameter grids for GridSearchCV
param_grids = {
    'Random Forest': {
        'estimator__n_estimators': [100, 200, 300],
        'estimator__max_depth': [None, 10, 20, 30],
        'estimator__min_samples_split': [2, 5, 10]
    },
    'Logistic Regression': {
        'estimator__C': [0.1, 1, 10],
        'estimator__penalty': ['l2']
    },
    'Support Vector Classifier': {
        'estimator__C': [0.1, 1, 10],
        'estimator__kernel': ['linear', 'rbf']
    },
    'Gradient Boosting': {
        'estimator__n_estimators': [100, 200],
        'estimator__learning_rate': [0.01, 0.1],
        'estimator__max_depth': [3, 5]
    }
}

# Initialize dictionary to store accuracy scores
model_accuracies = {}

# Function to train and evaluate models
def train_and_evaluate(model_name, model, param_grid):
    print(f"\nTraining and evaluating {model_name}...")
    
    # Wrap the model with MultiOutputClassifier
    multi_target_model = MultiOutputClassifier(model, n_jobs=-1)
    
    # Hyperparameter tuning
    grid_search = GridSearchCV(multi_target_model, param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    
    # Print classification reports and calculate accuracy
    print(f"Best parameters for {model_name}:", grid_search.best_params_)
    accuracies = []
    for i, column in enumerate(target.columns):
        print(f"\nClassification report for {column} using {model_name}:")
        print(classification_report(y_test[column], y_pred[:, i]))
        
        accuracy = accuracy_score(y_test[column], y_pred[:, i])
        accuracies.append(accuracy)
    
    # Store the average accuracy for the model
    model_accuracies[model_name] = sum(accuracies) / len(accuracies)
    
    # Confusion matrices for each target variable
    for i, column in enumerate(target.columns):
        conf_matrix = confusion_matrix(y_test[column], y_pred[:, i])
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Weak', 'Weak'],
                    yticklabels=['Not Weak', 'Weak'])
        plt.title(f'Confusion Matrix for {column} using {model_name}')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()

# Train and evaluate all models
for name, model in models.items():
    train_and_evaluate(name, model, param_grids[name])

# Plot the comparison of model accuracies
plt.figure(figsize=(10, 6))
sns.barplot(x=list(model_accuracies.keys()), y=list(model_accuracies.values()), palette='viridis')
plt.title('Comparison of Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Average Accuracy')
plt.ylim(0, 1)
plt.show()
